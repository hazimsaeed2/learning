# %% [markdown]
# # Week 6-2 · TIO-01 — System Architecture for Automated Trading Systems
# **Module:** Trading Tech, Infra & Operations · **Type:** conceptual lecture (no shipped dataset)
#
# This lecture is about *architecture*, not a dataset — so this notebook **reproduces every quantitative
# idea in the lecture as runnable Python**: the latency hierarchy (human → software → FPGA), how a
# **market-data adapter** deciphers a binary exchange packet, how a **data normalizer** unifies two
# exchange formats, how the **FIX protocol** builds and parses an order, the **fat-finger RMS** range
# check, the **scale of market data**, and the **dispersion / implied-correlation** maths the instructor
# used to motivate the event store.
#
# Everything below runs with only the Python standard library + numpy (no external data, no yfinance).

# %% [markdown]
# ## 1. Components of a trading system
# The lecture lists what *any* trading system needs. We model them as a simple pipeline.

# %%
components = [
    "Market Data Adapter  (read & decipher exchange data)",
    "Data Warehouse       (storehouse of historical data)",
    "Operational Data Store(subset kept locally for this strategy)",
    "Trader's App / CEP    (where trading decisions are made)",
    "Order Manager (OMS)   (route orders + risk + 2-way comms)",
    "Risk Management (RMS)  (fat-finger + main order checks)",
    "Back-office record     (compliance: store 7 years)",
]
for i, c in enumerate(components, 1):
    print(f"{i}. {c}")
# Out:
# 1. Market Data Adapter  (read & decipher exchange data)
# 2. Data Warehouse       (storehouse of historical data)
# 3. Operational Data Store(subset kept locally for this strategy)
# 4. Trader's App / CEP    (where trading decisions are made)
# 5. Order Manager (OMS)   (route orders + risk + 2-way comms)
# 6. Risk Management (RMS)  (fat-finger + main order checks)
# 7. Back-office record     (compliance: store 7 years)

# %% [markdown]
# ## 2. Traditional vs automated: the response-time gap
# The instructor's central motivation for going algorithmic. A human's fastest reaction to a stimulus is
# ~0.15 s (the iPad colour-change game). Software systems react in single-digit microseconds; pure-hardware
# FPGA systems in tens of nanoseconds (~35 ns for the FPGA stage alone).

# %%
latencies = {
    "Human (alert)":        0.15,          # 150 ms  fastest measured tap
    "Human (typical)":      0.25,          # 250 ms
    "Software-only system": 5e-6,          # ~5 microseconds
    "FPGA hardware stage":  35e-9,          # 35 nanoseconds
}
print(f"{'system':<22}{'seconds':>14}{'vs human(150ms)':>18}")
human = latencies['Human (alert)']
for k, v in latencies.items():
    print(f"{k:<22}{v:>14.2e}{human/v:>17,.0f}x")
speedup = latencies['Human (alert)'] / latencies['FPGA hardware stage']
print(f"\nFPGA is ~{speedup:,.0f}x faster than the fastest human reaction.")
# Out:
# system                       seconds   vs human(150ms)
# Human (alert)               1.50e-01                1x
# Human (typical)             2.50e-01                1x
# Software-only system        5.00e-06           30,000x
# FPGA hardware stage         3.50e-08        4,285,714x
#
# FPGA is ~4,285,714x faster than the fastest human reaction.

# %% [markdown]
# ## 3. Hardware vs software path
# Data arrives at the **LAN card** (physical layer). Either the logic runs *on the card* in an FPGA (fast,
# rigid), or it travels via **PCI → CPU** where software (C++/Python) runs (flexible, slower). We add up a
# toy latency budget for each path.

# %%
# toy per-stage latencies (nanoseconds)
software_path = {"NIC receive":80, "PCI to CPU":250, "OS/kernel stack":900,
                 "app decode":600, "strategy logic":400, "build packet":300, "PCI+NIC send":330}
fpga_path     = {"NIC receive":40, "decode on FPGA":15, "logic on FPGA":20, "build+send on FPGA":35}
sw = sum(software_path.values()); fp = sum(fpga_path.values())
print(f"Software-path total : {sw:>6} ns  ({sw/1000:.2f} us)")
print(f"FPGA-path total     : {fp:>6} ns  ({fp/1000:.3f} us)")
print(f"FPGA is {sw/fp:.1f}x faster end-to-end in this toy budget.")
# Out:
# Software-path total :   2860 ns  (2.86 us)
# FPGA-path total     :    110 ns  (0.110 us)
# FPGA is 26.0x faster end-to-end in this toy budget.

# %% [markdown]
# ## 4. The market-data adapter: deciphering a binary packet
# Each exchange sends market data in its **own fixed-byte format**. The adapter knows the layout. We build
# a packet with `struct` (instrument id, bid, ask, bid-qty, ask-qty) and decode it back.

# %%
import struct
# layout: >I = uint32 instrument id, then 4 floats (bid, ask, bidqty, askqty)
fmt = ">Iffff"
raw = struct.pack(fmt, 14, 270.10, 270.14, 1200.0, 900.0)   # instrument 14 = 'AAPL'
print("raw bytes:", raw.hex())
instr, bid, ask, bidq, askq = struct.unpack(fmt, raw)
names = {14: "AAPL", 7: "MSFT", 3: "SBIN"}
print(f"decoded -> {names.get(instr,'?')}  bid={bid:.2f}  ask={ask:.2f}  "
      f"bidQty={bidq:.0f}  askQty={askq:.0f}  spread={ask-bid:.2f}")
# Out:
# raw bytes: 0000000e43870ccd438711ec4496000044610000
# decoded -> AAPL  bid=270.10  ask=270.14  bidQty=1200  askQty=900  spread=0.04

# %% [markdown]
# ## 5. The data normalizer: two exchanges, one order book
# Exchange A sends best-level fields; Exchange B sends *cumulative* depth that must be de-cumulated.
# The normalizer converts both into the same standard structure.

# %%
# Exchange A: already best bid/ask
ex_a = {"instr":"SBIN", "best_bid":542.10, "best_ask":542.35, "bidq":800, "askq":650}
# Exchange B: cumulative ask quantities at levels 1 and 1+2 -> must de-cumulate
ex_b_cum = {"instr":"SBIN", "ask_px":[542.40, 542.55], "ask_cumqty":[700, 1900]}

def normalize_a(d):
    return {"instr":d["instr"], "bid":d["best_bid"], "ask":d["best_ask"],
            "bidq":d["bidq"], "askq":d["askq"]}

def normalize_b(d):
    cum = d["ask_cumqty"]; lvl_qty = [cum[0]] + [cum[i]-cum[i-1] for i in range(1,len(cum))]
    return {"instr":d["instr"], "ask_px":d["ask_px"], "ask_levelqty":lvl_qty}

print("A normalized:", normalize_a(ex_a))
nb_ = normalize_b(ex_b_cum)
print("B de-cumulated level qty:", nb_["ask_levelqty"], "(was cumulative", ex_b_cum["ask_cumqty"], ")")
# Out:
# A normalized: {'instr': 'SBIN', 'bid': 542.1, 'ask': 542.35, 'bidq': 800, 'askq': 650}
# B de-cumulated level qty: [700, 1200] (was cumulative [700, 1900] )

# %% [markdown]
# ## 6. The FIX protocol: build & parse an order
# FIX is a standardized **tag=value** text protocol (SOH-delimited). The lecture sent a defensive AAPL buy.
# We build it and parse it back, then note *why* it is slow (text, bloaty).

# %%
SOH = chr(1)   # field separator
TAGS = {1:"Account",11:"ClOrdID",35:"MsgType",38:"OrderQty",44:"Price",
        48:"SecurityID",54:"Side",55:"Symbol"}
order = {1:"Q001", 11:"ORD123", 48:"AAPL", 44:265.01, 54:1, 38:100, 35:"D"}  # 54=1 buy, 35=D new
msg = SOH.join(f"{t}={v}" for t, v in order.items())
print("FIX message (| shown for SOH):")
print(msg.replace(SOH, "|"))

parsed = {int(t): v for t, v in (f.split("=") for f in msg.split(SOH))}
print("\nParsed:")
for t, v in parsed.items():
    print(f"  {t:>3} {TAGS.get(t,'?'):<11} = {v}")

# why FIX is bloaty: price as text vs as a 4-byte float
price_text_bytes = len("265.01")   # 6 chars = 6 bytes
price_float_bytes = 4
print(f"\nPrice as FIX text = {price_text_bytes} bytes vs binary float = {price_float_bytes} bytes "
      f"({price_text_bytes/price_float_bytes:.1f}x bigger).")
# Out:
# FIX message (| shown for SOH):
# 1=Q001|11=ORD123|48=AAPL|44=265.01|54=1|38=100|35=D
#
# Parsed:
#     1 Account     = Q001
#    11 ClOrdID     = ORD123
#    48 SecurityID  = AAPL
#    44 Price       = 265.01
#    54 Side        = 1
#    38 OrderQty    = 100
#    35 MsgType     = D
#
# Price as FIX text = 6 bytes vs binary float = 4 bytes (1.5x bigger).

# %% [markdown]
# ## 7. Fat-finger RMS: the typo guard
# The trader meant IV trigger 30.01% but fat-fingered 3.01%. The within-app RMS rejects values outside a
# logical range, **before** the order ever reaches the order manager.

# %%
RANGES = {"iv_trigger_pct": (10.0, 80.0), "order_qty": (1, 5000), "price": (0.01, 100000)}

def rms_check(param, value):
    lo, hi = RANGES[param]
    ok = lo <= value <= hi
    return ok, f"{param}={value} {'ACCEPT' if ok else f'REJECT (outside {lo}-{hi})'}"

for v in [30.01, 3.01, 95.0]:
    print(rms_check("iv_trigger_pct", v)[1])
# Out:
# iv_trigger_pct=30.01 ACCEPT
# iv_trigger_pct=3.01 REJECT (outside 10.0-80.0)
# iv_trigger_pct=95.0 REJECT (outside 10.0-80.0)

# %% [markdown]
# ## 8. The scale of the problem
# Why an operational data store (a *subset*) is essential: each exchange lists 100,000+ instruments and
# emits a few hundred GB/day, but a pairs strategy may watch only 2.

# %%
instruments_total = 100_000
data_per_day_gb   = 300            # "few hundred GB/day", compressed binary
watched           = 2             # e.g. crude month-1 vs month-2
tick_per_asset_mb = 200           # FAQ: a few hundred MB tick-by-tick / asset / day
print(f"Instruments listed      : {instruments_total:,}")
print(f"Market data per day     : ~{data_per_day_gb} GB (compressed)")
print(f"Instruments you watch   : {watched}  ->  {watched/instruments_total:.5%} of the universe")
print(f"Tick data, 1 asset/day  : ~{tick_per_asset_mb} MB")
print("=> keep a tiny operational-data-store subset, not the whole firehose.")
# Out:
# Instruments listed      : 100,000
# Market data per day     : ~300 GB (compressed)
# Instruments you watch   : 2  ->  0.00200% of the universe
# Tick data, 1 asset/day  : ~200 MB
# => keep a tiny operational-data-store subset, not the whole firehose.

# %% [markdown]
# ## 9. Dispersion strategy & implied correlation
# The lecture's deep example. Index variance is a function of component variances, weights, and the
# **pairwise correlation**. Assuming one *constant* correlation rho across all pairs:
#
# $$\sigma_I^2 = \sum_i w_i^2 \sigma_i^2 \; + \; \rho \sum_{i \neq j} w_i w_j \sigma_i \sigma_j$$
#
# Solve for the **implied correlation** the market is pricing, then decide the trade.

# %%
import numpy as np
w     = np.array([0.5, 0.5])          # two 50% components
sig_i = np.array([0.20, 0.20])        # component vols (annualised)
sig_I = 0.16                          # index vol implied from index options

# build the cross term sum_{i!=j} w_i w_j sig_i sig_j
M = np.outer(w*sig_i, w*sig_i)
diag = np.sum(np.diag(M))             # = sum w_i^2 sig_i^2
cross = np.sum(M) - diag              # sum over i!=j
implied_rho = (sig_I**2 - diag) / cross
print(f"diagonal (sum w^2 sig^2) = {diag:.4f}")
print(f"cross term coefficient   = {cross:.4f}")
print(f"Implied correlation rho  = {implied_rho:.3f}")

# decision rule from the lecture
if implied_rho < 0.5:
    trade = "market prices LOW correlation -> if it rises, index vol rises: BUY index vol, SELL stock vol"
else:
    trade = "market prices HIGH correlation -> if it falls, index vol falls: SELL index vol, BUY stock vol"
print("Trade:", trade)
# Out:
# diagonal (sum w^2 sig^2) = 0.0200
# cross term coefficient   = 0.0200
# Implied correlation rho  = 0.280
# Trade: market prices LOW correlation -> if it rises, index vol rises: BUY index vol, SELL stock vol

# %% [markdown]
# ### 9b. Sanity check: rho = +1 and rho = -1 bracket the index vol
# With two equal 50/50 components at 20% vol, perfectly correlated index vol = 20%, perfectly
# anti-correlated index vol = 0% (the flat index). Our 16% sits in between.

# %%
def index_vol(rho):
    var = diag + rho*cross
    return np.sqrt(max(var, 0.0))
for r in [1.0, 0.5, implied_rho, 0.0, -1.0]:
    print(f"rho={r:+.2f} -> index vol = {index_vol(r):.3f}")
# Out:
# rho=+1.00 -> index vol = 0.200
# rho=+0.50 -> index vol = 0.173
# rho=+0.28 -> index vol = 0.160
# rho=+0.00 -> index vol = 0.141
# rho=-1.00 -> index vol = 0.000

# %% [markdown]
# ## 10. Quantified news: the four scores
# Vendors (Thomson Reuters, RavenPack/Dow Jones, Bloomberg) attach scores to each article so machines can
# act. We model the four the instructor named and a tiny novelty de-duplicator.

# %%
articles = [
    {"id":1, "text":"CEO ABC fined $20 million by regulator", "companies":["ABC"]},
    {"id":2, "text":"CEO ABC fined $20 million, to pay in two months", "companies":["ABC"]},
    {"id":3, "text":"XYZ posts record quarterly profit, shares jump", "companies":["XYZ"]},
]
pos_words = {"profit","record","jump","beat","up","gain"}
neg_words = {"fined","loss","fraud","down","cut"}

def sentiment(t):
    toks = set(t.lower().replace(",", " ").replace("$"," ").split())
    p, n = len(toks & pos_words), len(toks & neg_words)
    return (p - n) / max(p + n, 1)

seen = []   # novelty: reject if too similar to a prior article on same company
def novelty(t, companies):
    for s in seen:
        if companies == s[0] and len(set(t.lower().split()) & set(s[1].lower().split())) >= 4:
            return 0.0
    seen.append((companies, t)); return 1.0

for a in articles:
    s = sentiment(a["text"]); nov = novelty(a["text"], a["companies"])
    print(f"id{a['id']}  sentiment={s:+.2f}  relevance=1.0(single co)  novelty={nov:.0f}  "
          f"{'ACT' if nov>0 else 'SKIP (repeat)'}  :: {a['text']}")
# Out:
# id1  sentiment=-1.00  relevance=1.0(single co)  novelty=1  ACT  :: CEO ABC fined $20 million by regulator
# id2  sentiment=-1.00  relevance=1.0(single co)  novelty=0  SKIP (repeat)  :: CEO ABC fined $20 million, to pay in two months
# id3  sentiment=+1.00  relevance=1.0(single co)  novelty=1  ACT  :: XYZ posts record quarterly profit, shares jump

# %% [markdown]
# ## 11. The simulator & data replay
# A new strategy is *not* sent live. It is run against an **exchange simulator** fed by **replayed historical
# data** (flat day, volatile day, gap-up...). We model a probabilistic fill for a passive order sitting
# between bid and ask.

# %%
import numpy as np
rng = np.random.default_rng(7)

def fill_probability(order_px, bid, ask):
    # aggressive (>= ask) -> ~certain; passive deep below bid -> ~0; in-spread -> linear-ish
    if order_px >= ask: return 0.99
    if order_px <= bid: return 0.05
    frac = (order_px - bid) / (ask - bid)     # 0 at bid, 1 at ask
    return 0.05 + 0.9*frac

bid, ask = 99.00, 100.00
for px in [98.50, 99.00, 99.50, 99.99, 100.00]:
    p = fill_probability(px, bid, ask)
    fills = rng.random(10000) < p
    print(f"order@{px:>6.2f}  P(fill)={p:.2f}  simulated fill rate={fills.mean():.2f}")
# Out:
# order@ 98.50  P(fill)=0.05  simulated fill rate=0.05
# order@ 99.00  P(fill)=0.05  simulated fill rate=0.05
# order@ 99.50  P(fill)=0.50  simulated fill rate=0.50
# order@ 99.99  P(fill)=0.94  simulated fill rate=0.94
# order@100.00  P(fill)=0.99  simulated fill rate=0.99

# %% [markdown]
# ## Key takeaways
# - A trading system = **market-data adapter → (data warehouse / operational data store) → trader's app/CEP → order manager (with RMS) → exchange**, plus back-office record-keeping (7 yrs).
# - Going algorithmic closes a **~4-million-to-one** reaction-time gap (human 150 ms vs FPGA 35 ns) and scales from ~50 to tens of thousands of instruments.
# - **Hardware (FPGA on the NIC)** is fast but rigid; **software (PCI→CPU)** is flexible but slower.
# - Each exchange speaks its **own binary language**; the **adapter** deciphers it and the **normalizer** unifies formats; **FIX** is a standard but text-based (bloaty, slower).
# - **RMS** lives both in the app (fat-finger typo guard) and — more importantly — once, just before orders leave the **order manager**.
# - The **dispersion** example: index variance = component variances + pairwise correlation; solving for the constant **implied correlation** tells you whether to buy or sell index vol vs stock vol.
# - Strategies are validated on an **exchange simulator** with **replayed data** before going live; good simulators are proprietary and demand deep market-microstructure knowledge.

# %% [markdown]
# ---
#
# # Validated additive resource section
#
# The cells below were appended during validation to cover exchange-side and infrastructure details while preserving every original cell above.

# %% [markdown]
# # Week 6-2 Resource Addendum - Exchange Side and Infrastructure Details
#
# This additive notebook fills details that sit after the main architecture story: exchange-side routing, market-data feed types, order-manager queues, co-location/connectivity, retail infrastructure FAQs, and deeper quantified-news scoring.

# %%
from pathlib import Path
import math
import struct
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

DATA_DIR = Path.cwd()
print("setup complete")
print("working directory:", DATA_DIR)
# Out:
# setup complete
# working directory: C:\Users\hsaeed\Downloads\EPAT-Git\_validation_work\tio01\notebook_exec_20260702_093713

# %% [markdown]
# ## 1. Exchange-side architecture
#
# The trading server is not talking to one monolithic exchange box. Orders enter gateways, gateways route by instrument to matching engines, and separate streams publish market data, recovery packets, and drop-copy reports.

# %%
exchange = pd.read_csv("tio01_exchange_architecture_components.csv")
display(exchange)

instruments = {"AAPL": "ME-1", "MSFT": "ME-1", "CL_F1": "ME-2", "CL_F2": "ME-2", "NIFTY_OPT": "ME-3"}
orders = pd.DataFrame({"order_id": [1, 2, 3], "symbol": ["AAPL", "CL_F2", "NIFTY_OPT"], "side": ["BUY", "SELL", "BUY"]})
orders["gateway"] = ["GW-A", "GW-B", "GW-A"]
orders["matching_engine"] = orders["symbol"].map(instruments)
display(orders)
print("Gateway routes each order to the matching engine that owns that instrument book.")
# Out:
#                       component                zone  \
# 0                Trading server         Member side
# 1              Exchange gateway       Exchange edge
# 2               Matching engine       Exchange core
# 3    Primary market data server       Exchange data
# 4  Secondary market data server       Exchange data
# 5               Snapshot server       Exchange data
# 6               Recovery server       Exchange data
# 7              Drop copy server  Exchange/reporting
#
#                                                 role  \
# 0     Sends order requests and receives acks/reports
# 1  Authenticates session, applies rate/format che...
# 2  Maintains order books and matches orders for a...
# 3                 Publishes live market data updates
# 4                          Backup market data source
# 5           Publishes periodic or top-book snapshots
# 6         Resends missed packets by sequence request
# 7  Sends a copy of all trades/reports to risk or ...
#
#                        communication
# 0    TCP session to exchange gateway
# 1              One-to-one order flow
# 2      Receives orders from gateways
# 3  Usually multicast/broadcast style
# 4               Failover market data
# 5           Market data subscription
# 6            One-to-one TCP recovery
# 7        Authenticated report stream
#    order_id     symbol  side gateway matching_engine
# 0         1       AAPL   BUY    GW-A            ME-1
# 1         2      CL_F2  SELL    GW-B            ME-2
# 2         3  NIFTY_OPT   BUY    GW-A            ME-3
# Gateway routes each order to the matching engine that owns that instrument book.

# %% [markdown]
# ## 2. Market-data methods
#
# Snapshot, tick-by-tick, and snapshot TBT have different data volume, immediacy, and book-maintenance burdens. TBT users must build and maintain an order book from events.

# %%
md_methods = pd.read_csv("tio01_market_data_methods.csv")
display(md_methods)

events = [
    {"event": "ADD", "side": "B", "price": 99.00, "qty": 500},
    {"event": "ADD", "side": "S", "price": 100.00, "qty": 400},
    {"event": "ADD", "side": "B", "price": 99.50, "qty": 250},
    {"event": "MOD", "side": "S", "price": 100.00, "qty": 250},
    {"event": "CXL", "side": "B", "price": 99.00, "qty": 500},
]
book = {"B": {}, "S": {}}
snapshots = []
for i, event in enumerate(events, start=1):
    side_book = book[event["side"]]
    if event["event"] in {"ADD", "MOD"}:
        side_book[event["price"]] = event["qty"]
    elif event["event"] == "CXL":
        side_book.pop(event["price"], None)
    best_bid = max(book["B"], default=np.nan)
    best_ask = min(book["S"], default=np.nan)
    snapshots.append({"seq": i, "event": event["event"], "best_bid": best_bid, "best_ask": best_ask})
display(pd.DataFrame(snapshots))
print("TBT gives control and speed, but book correctness becomes your responsibility.")
# Out:
#          method                                    trigger  \
# 0      Snapshot             Every configured time interval
# 1  Tick by tick  Every order/add/cancel/modify/trade event
# 2  Snapshot TBT                         Top N book changes
#
#                                    user_work  data_volume_score  \
# 0             No full order-book maintenance                  1
# 1  Maintain the order book from event stream                  5
# 2    No full book maintenance for top levels                  4
#
#    immediacy_score                                         best_for
# 0                1  Lower-frequency users without microsecond needs
# 1                5                    HFT, market making, arbitrage
# 2                4          Fast users focused on top-of-book depth
#    seq event  best_bid  best_ask
# 0    1   ADD      99.0       NaN
# 1    2   ADD      99.0     100.0
# 2    3   ADD      99.5     100.0
# 3    4   MOD      99.5     100.0
# 4    5   CXL      99.5     100.0
# TBT gives control and speed, but book correctness becomes your responsibility.

# %% [markdown]
# ## 3. Order-manager queues
#
# Two internal queues matter: a message-rate queue and an acknowledgement queue. A replace/cancel cannot be safely sent until the exchange acknowledges the original order and returns identifiers required by protocol.

# %%
queues = pd.read_csv("tio01_order_manager_queues.csv")
display(queues)

order_rate_limit = 3
request_times = [0.05, 0.10, 0.20, 0.40, 1.05]
sent_in_second = 0
accepted = []
for t in request_times:
    second = int(t)
    if second == 0 and sent_in_second >= order_rate_limit:
        accepted.append(False)
    else:
        accepted.append(True)
        if second == 0:
            sent_in_second += 1
display(pd.DataFrame({"request_time_sec": request_times, "sent_immediately": accepted}))

ack_received = False
can_replace_before_ack = ack_received
ack_received = True
exchange_order_id = "EX12345"
exchange_timestamp = "09:15:00.123456"
can_replace_after_ack = ack_received and exchange_order_id and exchange_timestamp
print("replace before ack:", can_replace_before_ack)
print("replace after ack:", bool(can_replace_after_ack), exchange_order_id, exchange_timestamp)
# Out:
#                    queue                                      why_it_exists  \
# 0     Message-rate queue  Exchange sells/limits order messages per secon...
# 1  Acknowledgement queue  Cancel/replace needs exchange order ID and som...
# 2          Gateway queue  Exchange-side gateway and matching engine load...
#
#                                     blocks_when  \
# 0       Current second has used its order quota
# 1  Original order has not been acknowledged yet
# 2                      Exchange traffic is high
#
#                            safe_action
# 0      Hold until the next time bucket
# 1   Wait for ack before replace/cancel
# 2  Model variable latency in simulator
#    request_time_sec  sent_immediately
# 0              0.05              True
# 1              0.10              True
# 2              0.20              True
# 3              0.40             False
# 4              1.05              True
# replace before ack: False
# replace after ack: True EX12345 09:15:00.123456

# %% [markdown]
# ## 4. Connectivity and co-location
#
# The lecture's connectivity story moves from long fiber paths toward straighter physical paths and then co-location. Co-location is mainly justified for low-latency/HFT strategies.

# %%
latency = pd.read_csv("tio01_connectivity_latency_reference.csv")
display(latency)

fig, ax = plt.subplots(figsize=(9, 4))
plot_data = latency.iloc[:5]
ax.bar(plot_data["route"], plot_data["latency_ms"], color=["#7f1d1d", "#be123c", "#d97706", "#0f766e", "#334155"])
ax.set_ylabel("Latency (ms)")
ax.set_title("Connectivity path improvements")
ax.tick_params(axis="x", rotation=25)
ax.grid(True, axis="y", alpha=0.25)
plt.tight_layout()
plt.show()

legacy = float(latency.loc[latency["route"] == "Legacy fiber", "latency_ms"].iloc[0])
shortwave = float(latency.loc[latency["route"] == "Shortwave / RF path", "latency_ms"].iloc[0])
coloc = float(latency.loc[latency["route"] == "Co-located one-way", "latency_ms"].iloc[0])
print("legacy fiber vs shortwave improvement:", round(legacy / shortwave, 2), "x")
print("legacy fiber vs co-located one-way path:", round(legacy / coloc), "x")
# Out:
#                  route  latency_ms  \
# 0         Legacy fiber       18.00
# 1     Straighter fiber       13.50
# 2     Microwave towers        7.50
# 3  Shortwave / RF path        4.00
# 4    Physics reference        3.50
# 5   Co-located one-way        0.02
#
#                                                 note
# 0               Fiber follows existing rights-of-way
# 1            Shorter dug route under lakes/mountains
# 2                      Near straight-line tower hops
# 3                     Closer to speed-of-light limit
# 4  Approximate straight-line lower bound mentione...
# 5          Around 20 microseconds to matching engine
# legacy fiber vs shortwave improvement: 4.5 x
# legacy fiber vs co-located one-way path: 900 x

# %% [markdown]
# ## 5. Quantified news scoring
#
# The lecture named sentiment, relevance, novelty, and market impact. The companion quantified-news deck adds that sentiment should be entity-level, relevance depends on how central the company is, novelty is checked within and across feeds, and impact can use article/social volume.

# %%
news_ref = pd.read_csv("tio01_news_scoring_reference.csv")
display(news_ref)

articles = pd.DataFrame([
    {"id": 1, "headline": "ABC beats estimates", "entity": "ABC", "sentiment": 0.92, "relevance": 0.98, "linked_count": 0, "impact": 0.80},
    {"id": 2, "headline": "ABC beats estimates in update", "entity": "ABC", "sentiment": 0.90, "relevance": 0.90, "linked_count": 4, "impact": 0.45},
    {"id": 3, "headline": "Supplier DEF warns on demand", "entity": "DEF", "sentiment": -0.88, "relevance": 0.95, "linked_count": 0, "impact": 0.75},
    {"id": 4, "headline": "Market wrap mentions ABC", "entity": "ABC", "sentiment": 0.45, "relevance": 0.20, "linked_count": 0, "impact": 0.15},
])
articles["novelty"] = 1 / (1 + articles["linked_count"])
articles["trade_score"] = articles["sentiment"].abs() * articles["relevance"] * articles["novelty"] * articles["impact"]
articles["candidate"] = articles["trade_score"] >= 0.50
display(articles)
print("High sentiment is filtered out if relevance, novelty, or impact is weak.")
# Out:
#              score                                            meaning  \
# 0        Sentiment    Tone for an entity, not just the whole document
# 1        Relevance          How central the company is to the article
# 2          Novelty  Whether this is new or a repeat of an already ...
# 3    Market impact     Expected price importance of the news category
# 4  Strategy filter         Quality threshold for trading news signals
#
#                                        common_inputs  \
# 0  Keyword polarity, grammar, negation, ML classi...
# 1  Headline mention, mention count, article lengt...
# 2  Similarity to linked historical articles withi...
# 3          Event type, article volume, social volume
# 4  High sentiment/relevance threshold, hedged lon...
#
#                                             pitfall
# 0          Document sentiment can differ by company
# 1       Synonyms and company aliases must be mapped
# 2      Repeated alerts can trigger duplicate trades
# 3  High sentiment without impact may not trade well
# 4             More news is not automatically better
#    id                       headline entity  sentiment  relevance  \
# 0   1            ABC beats estimates    ABC       0.92       0.98
# 1   2  ABC beats estimates in update    ABC       0.90       0.90
# 2   3   Supplier DEF warns on demand    DEF      -0.88       0.95
# 3   4       Market wrap mentions ABC    ABC       0.45       0.20
#
#    linked_count  impact  novelty  trade_score  candidate
# 0             0    0.80      1.0      0.72128       True
# 1             4    0.45      0.2      0.07290      False
# 2             0    0.75      1.0      0.62700       True
# 3             0    0.15      1.0      0.01350      False
# High sentiment is filtered out if relevance, novelty, or impact is weak.

# %% [markdown]
# ## 6. Retail infrastructure FAQ checks
#
# The FAQ adds practical boundaries: beginners should start with LFT, broker paths can be measured in pieces, paper trading differs from replay, and co-location is not needed unless the strategy is latency-sensitive.

# %%
faq = pd.read_csv("tio01_retail_infra_faq.csv")
display(faq)

strategy_profiles = pd.DataFrame([
    {"strategy": "Daily moving-average rotation", "latency_need": 1, "message_rate": 1, "recommended_setup": "Broker/cloud or platform"},
    {"strategy": "Intraday statistical arbitrage", "latency_need": 3, "message_rate": 3, "recommended_setup": "Dedicated server, broker API, good monitoring"},
    {"strategy": "HFT market making", "latency_need": 5, "message_rate": 5, "recommended_setup": "Co-location, TBT feed, native protocol"},
])
display(strategy_profiles)
print("Infrastructure should fit the strategy; there is no single optimal architecture.")
# Out:
#                                question  \
# 0         Where should beginners start?
# 1  Do retail orders use DMA by default?
# 2      How do I measure broker latency?
# 3   How do I test outside market hours?
# 4        When is co-location justified?
# 5      How much TBT data for one asset?
# 6     Does TBT include an initial book?
#
#                                               answer
# 0  Start with low-frequency trading, then expand ...
# 1  Usually they route through a broker; DMA becom...
# 2  Measure local-to-broker with ping; ask broker ...
# 3  Use a market simulator and replay stored data;...
# 4  Mostly for low-latency or HFT strategies; slow...
# 5  The FAQ says a single asset can produce a few ...
# 6  The order book starts fresh each day and algor...
#                          strategy  latency_need  message_rate  \
# 0   Daily moving-average rotation             1             1
# 1  Intraday statistical arbitrage             3             3
# 2               HFT market making             5             5
#
#                                recommended_setup
# 0                       Broker/cloud or platform
# 1  Dedicated server, broker API, good monitoring
# 2         Co-location, TBT feed, native protocol
# Infrastructure should fit the strategy; there is no single optimal architecture.

# %% [markdown]
# ## Addendum summary
#
# - Exchange order flow passes through gateways to matching engines; market data, recovery, and drop copy are separate streams.
# - Snapshot, TBT, and snapshot TBT differ by immediacy, volume, and who maintains the book.
# - Order managers need message-rate and acknowledgement queues.
# - Co-location solves physical latency only when the strategy needs it.
# - Quantified news needs sentiment, relevance, novelty, impact, and quality filters.
